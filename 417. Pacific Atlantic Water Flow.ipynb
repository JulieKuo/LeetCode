# %% [markdown]
# ### 417. Pacific Atlantic Water Flow

# %%
class Solution():
    def pacificAtlantic(self, heights):
        p_land = set() # 保存可流入太平洋的座標
        a_land = set() # 保存可流入大西洋的座標
        R, C = len(heights), len(heights[0])
        print(f"R = {R}, C= {C}")

        def spread(r, c, land):
            land.add((r, c)) # 保存可流入海洋的座標
            print("-" * 200)
            print(f"r = {r}, c = {c}")
            print(f"land = {land}")
            
            for r1, c1 in ((r-1, c), (r, c-1), (r+1, c), (r, c+1)): # 上下左右
                if (0 <= r1 < R) and (0 <= c1 < C): # 座標在範圍內 
                    print(f"- r1 = {r1}, c1 = {c1}")
                    if (heights[r1][c1] >= heights[r][c]) and ((r1, c1) not in land): # 座標可流入海洋
                        print(f"- ((heights[r1][c1] = {heights[r1][c1]}) >= (heights[r][c] = {heights[r][c]}))")
                        spread(r1, c1, land) # 查看該座標的上下左右
        
        # 周圍一定會流進海洋
        for i in range(R):
            print("_"*200)
            spread(i, 0, p_land) # 左側進太平洋
            print("_"*200)
            spread(i, C-1, a_land) # 右側進大西洋

        print("=" * 200)

        for j in range(C):
            print("_"*200)
            spread(0, j, p_land) # 上側進太平洋
            print("_"*200)
            spread(R-1, j, a_land) # 下側進大西洋
            
        return list(p_land & a_land) # 兩海洋交集的座標

# %% [markdown]
# Input: heights = [[1,2,2,3,5],[3,2,3,4,4],[2,4,5,3,1],[6,7,1,4,5],[5,1,1,2,4]]
# Output: [[0,4],[1,3],[1,4],[2,2],[3,0],[3,1],[4,0]]

# %%
heights = [
    [1,2,2,3,5],
    [3,2,3,4,4],
    [2,4,5,3,1],
    [6,7,1,4,5],
    [5,1,1,2,4]
    ]
Solution().pacificAtlantic(heights)
# Out:
# R = 5, C= 5
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# r = 0, c = 0
# land = {(0, 0)}
# - r1 = 1, c1 = 0
# - ((heights[r1][c1] = 3) >= (heights[r][c] = 1))
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# r = 1, c = 0
# land = {(1, 0), (0, 0)}
# - r1 = 0, c1 = 0
# - r1 = 2, c1 = 0
# - r1 = 1, c1 = 1
# - r1 = 0, c1 = 1
# - ((heights[r1][c1] = 2) >= (heights[r][c] = 1))
# ...
