# %% [markdown]
# ### 269. Alien Dictionary (Extract Alphabet)

# %% [markdown]
# #### Question
# You are given a dictionary of words that has been lexicographically sorted with a permutation of the standard English alphabet (same letters, different order). Using the dictionary, find the alphabet (an ordered list of characters).
#
# For example, if the dictionary orders words like
#
# ```
# RAT
# ART
# CAT
# CAR
# ```
#
# Then the solution should return a list with the characters in the order
#
# ```
# T, R, A, C
# ```
#
# Hint: T comes before R that comes before A that comes before C

# %% [markdown]
# **時間複雜度: $O( N + V + E )$**
# **空間複雜度: $O( V + E )$**
#
# 在圖論面試的標準對答中，因為一條「邊（Edge）」一定是由兩個單字比較而產生的，所以邊的總數 $E$ 絕對不可能超過單字配對的總數 $W - 1$。
# 既然 $E \le W \le N$，$O(N + V + E)$ 通常可以直接簡寫為 $O(N + V)$。
#
# - $W$：單字列表中的單字總數量（len(words)）
# - $N$：所有單字字元長度的總和（即所有字母總數）
# - $V$：所有不同的字母數量（Graph 中的節點數）
# - $E$：字母之間的順序關係（Graph 中的邊數，且 $E \le W-1$）

# %% [markdown]
# #### BFS

# %%
from typing import List
from collections import defaultdict, deque

class Solution:
    def foreignDictionary(self, words: List[str]) -> str:
        # 建立入度表（indegree）記錄每個字母被多少其他字母指向
        indegree = {} # space: O(V)
        for word in words: # 雙層迴圈總共走訪所有字元，time: O(N)
            for char in word:
                indegree[char] = 0  # 初始入度皆為 0

        # 建立鄰接表（adjacency）表示圖中每個節點（字母）及其相鄰節點（後繼字母）
        adjacency = defaultdict(set) # space: O(V + E)

        # 逐對比較相鄰的單字。所有相鄰配對比較的字元數總和，最壞情況下為 O(N)
        for i in range(len(words) - 1): # 執行 W - 1 次
            word1 = words[i]
            word2 = words[i + 1]
            min_len = min(len(word1), len(word2))

            # 若 word1 是 word2 的前綴且比它長，代表無效（例如 ["abc", "ab"]）
            if (len(word1) > len(word2)) and (word1[:min_len] == word2[:min_len]):
                return ""  # 無效字典，回傳空字串
                
            # 找出第一個不相同的字母，推斷出它們的順序
            for j in range(min_len):
                char1 = word1[j]
                char2 = word2[j]
                if char1 != char2:
                    # 若 char1 -> char2 尚未記錄，加入鄰接表並更新入度
                    if char2 not in adjacency[char1]:
                        adjacency[char1].add(char2) # 整體最多建立 E 條邊，每次操作 O(1)
                        indegree[char2] += 1
                    break  # 找到第一個不同字母後即可停止內層比較

        # 將所有入度為 0 的字母放入佇列
        queue = deque([]) # space: O(V)
        for char, pre_count in indegree.items(): # time: O(V)
            if pre_count == 0:
                queue.append(char)
        
        result = [] # space: O(V)

        # 拓撲排序（BFS 寬度優先搜尋），整體時間複雜度: O(V + E)
        while queue: # 每個節點最多進出佇列一次，time: O(V)
            char = queue.popleft()
            result.append(char)

            # 將相鄰節點的入度減 1。在整個 BFS 過程中，每條邊最多被走訪一次
            for next_char in adjacency[char]: # 整體執行次數總和為 O(E)
                indegree[next_char] -= 1
                if indegree[next_char] == 0:
                    queue.append(next_char)
        
        # 若結果字母數量不等於所有字母總數，代表存在循環
        if len(result) != len(indegree):
            return ""

        return "".join(result)

# %%
words = ["hrn","hrf","er","enn","rfnn"]
# Output: "hernf"

Solution().foreignDictionary(words)
# Out:
# 'hernf'

# %% [markdown]
# #### DFS

# %%
from typing import List
from collections import defaultdict

class Solution:
    def foreignDictionary(self, words: List[str]) -> str:
        # 用一個字典初始化所有字母的狀態：0 = 未訪問, 1 = 訪問中, 2 = 已訪問
        visited = {} # space: O(V)
        for word in words: # 雙層迴圈走訪所有字元，time: O(N)
            for char in word:
                visited[char] = 0  # 初始皆為 0

        adjacency = defaultdict(set) # space: O(V + E)

        # 逐對比較相鄰的單字，整體字元比較與建圖的時間複雜度為 O(N)
        for i in range(len(words) - 1): 
            word1 = words[i]
            word2 = words[i + 1]
            min_len = min(len(word1), len(word2))

            # 若 word1 是 word2 的前綴且比它長，代表無效
            if (word1[:min_len] == word2[:min_len]) and (len(word1) > len(word2)):
                return ""  
                
            for j in range(min_len):
                char1 = word1[j]
                char2 = word2[j]
                if char1 != char2:
                    if char2 not in adjacency[char1]:
                        adjacency[char1].add(char2) # 整體最多建立 E 條邊
                    break  

        result = [] # space: O(V)

        # 定義 DFS 遞迴函式
        def dfs(char):
            if visited[char] == 1:  # 撞到狀態 1 -> 代表有環
                return False
            if visited[char] == 2:  # 撞到狀態 2 -> 代表安全
                return True
                
            visited[char] = 1  # 標記為「訪問中」
            
            # 遞迴訪問所有相鄰節點。整個 DFS 流程中，每條邊只會被遍歷一次
            for neighbor in adjacency[char]: # 單次迴圈複雜度取決於出度，整體加總為 O(E)
                state = dfs(neighbor)
                if not state:  
                    return False
                
            visited[char] = 2  # 標記為「已完成訪問」
            result.append(char)   # 後序加入結果
            return True

        # 逐一對每個節點進行 DFS。
        # 這裡外層迴圈本身是 O(V)，配合內部 dfs 呼叫，整個圖遍歷的時間複雜度為 O(V + E)
        for char in visited:  
            if visited[char] == 0:
                state = dfs(char)
                if not state:
                    return ""  
            
        result.reverse()  # time: O(V)

        return "".join(result)

# %%
words = ["hrn","hrf","er","enn","rfnn"]
# Output: "hernf"

Solution().foreignDictionary(words)
# Out:
# 'hernf'
